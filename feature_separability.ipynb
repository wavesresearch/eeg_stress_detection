# %%
# %run feature_generator/spectral.ipynb
# %run feature_generator/sample_entropy.ipynb
# %run feature_generator/spectral_entropy.ipynb
# %run feature_generator/stats.ipynb
# %run feature_generator/hjorth.ipynb
# %run feature_generator/entropies.ipynb
# %run load_labels.ipynb

# %%
data = features

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
num_classes = 2
channels = 32
sfreq = 128

# %%
labels = load_labels()
label = pd.concat([labels['t1_math'], labels['t2_math'],
                  labels['t3_math']]).to_numpy()
label = label.repeat(data.shape[0]//label.shape[0])

# %%
plt.scatter(data[label == False][:, :channels:channels], data[label == False][:, channels:channels*2:channels], label="Non-stressed")
plt.scatter(data[label == True][:, :channels:channels], data[label == True][:, channels:channels*2:channels], label="Stressed")
plt.legend()
plt.xlabel("Variance")
plt.ylabel("RMS")
plt.title("Class Overlap for Variance and RMS")
# Out:
# Text(0.5, 1.0, 'Class Overlap for Variance and RMS')

# %%
plt.scatter(data[label == False][:, :channels:channels], data[label == False][:, channels*2:channels*3:channels], label="Non-stressed")
plt.scatter(data[label == True][:, :channels:channels], data[label == True][:, channels*2:channels*3:channels], label="Stressed")
plt.legend()
plt.xlabel("Variance")
plt.ylabel("RMS")
plt.title("Class Overlap for Variance and RMS")
# Out:
# Text(0.5, 1.0, 'Class Overlap for Variance and RMS')

# %%
plt.scatter(data[label == False][:, :channels:channels], data[label == False][:, channels*3:channels*4:channels], label="Non-stressed")
plt.scatter(data[label == True][:, :channels:channels], data[label == True][:, channels*3:channels*4:channels], label="Stressed")
plt.legend()
plt.xlabel("Variance")
plt.ylabel("RMS")
plt.title("Class Overlap for Variance and RMS")
# Out:
# Text(0.5, 1.0, 'Class Overlap for Variance and RMS')

# %%
plt.scatter(data[label == False][:, channels:channels*2:channels], data[label == False][:, channels*2:channels*3:channels], label="Non-stressed")
plt.scatter(data[label == True][:, channels:channels*2:channels], data[label == True][:, channels*2:channels*3:channels], label="Stressed")
plt.legend()
plt.xlabel("Variance")
plt.ylabel("RMS")
plt.title("Class Overlap for Variance and RMS")
# Out:
# Text(0.5, 1.0, 'Class Overlap for Variance and RMS')

# %%
plt.scatter(data[label == False][:, channels:channels*2:channels], data[label == False][:, channels*3:channels*4:channels], label="Non-stressed")
plt.scatter(data[label == True][:, channels:channels*2:channels], data[label == True][:, channels*3:channels*4:channels], label="Stressed")
plt.legend()
plt.xlabel("Variance")
plt.ylabel("RMS")
plt.title("Class Overlap for Variance and RMS")
# Out:
# Text(0.5, 1.0, 'Class Overlap for Variance and RMS')

# %%
plt.scatter(data[label == False][:, channels*2:channels*3:channels], data[label == False][:, channels*3:channels*4:channels], label="Non-stressed")
plt.scatter(data[label == True][:, channels*2:channels*3:channels], data[label == True][:, channels*3:channels*4:channels], label="Stressed")
plt.legend()
plt.xlabel("Variance")
plt.ylabel("RMS")
plt.title("Class Overlap for Variance and RMS")
# Out:
# Text(0.5, 1.0, 'Class Overlap for Variance and RMS')
