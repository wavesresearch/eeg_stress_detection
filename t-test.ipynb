# %%
import numpy as np
import scipy
import pandas as pd

# %%
from dataset import load_dataset, load_labels, convert_to_epochs, format_labels
from features import time_series_features, fractal_features, entropy_features, hjorth_features, freq_band_features

# %% [markdown]
# ## Variables

# %%
n_classes = 2
n_channels = 32
sfreq = 128

# %%
data_type = "ica_filtered"
test_type = "Arithmetic"

# %% [markdown]
# ## Load Data

# %%
dataset_ = load_dataset(data_type=data_type, test_type=test_type)
dataset = convert_to_epochs(dataset_, n_channels, sfreq)

# %%
label_ = load_labels()
label = format_labels(label_, test_type=test_type, epochs=dataset.shape[1])

# %% [markdown]
# ## Compute Features

# %%
# features = time_series_features(dataset, n_channels)
# freq_bands = np.array([1, 4, 8, 13, 31, 50])
# features = freq_band_features(dataset, n_channels, sfreq, freq_bands)
# features = fractal_features(dataset, n_channels)
features = hjorth_features(dataset, n_channels, sfreq)
# features = entropy_features(dataset, n_channels, sfreq)

# %% [markdown]
# ## Split Data

# %%
stressed_data = features[np.where(label != 0)]
non_stressed_data = features[np.where(label == 0)]

# %% [markdown]
# ## Compute t-tests

# %%
P = np.zeros(features.shape[1])
for j, i in enumerate(range(features.shape[1])):
    _, p = scipy.stats.ttest_ind(stressed_data[:, i], non_stressed_data[:, i])
    P[j] = p

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
pd.DataFrame(P)
# Out:
#                0
# 0   8.565707e-09
# 1   4.199706e-01
# 2   9.243714e-04
# 3   2.969316e-01
# 4   7.612570e-03
# 5   7.449619e-01
# 6   9.528565e-02
# 7   8.299859e-01
# 8   6.632852e-01
# 9   7.414754e-03
# 10  5.860924e-05
# 11  2.434920e-02
# 12  1.278021e-01
# 13  2.940169e-05
# 14  7.768960e-07
# 15  1.016899e-05
# 16  1.985319e-02
# 17  1.070608e-01
# 18  5.213117e-06
# 19  1.358506e-22
# 20  1.255365e-18
# 21  2.182334e-06
# 22  3.866509e-08
# 23  1.044755e-05
# 24  4.995159e-03
# 25  2.483783e-01
# 26  4.591010e-05
# 27  5.557755e-05
# 28  5.001415e-04
# 29  8.098234e-01
# 30  1.842379e-01
# 31  2.943885e-01
# 32  1.492710e-02
# 33  2.327972e-03
# 34  3.122502e-06
# 35  4.874759e-02
# 36  6.426229e-01
# 37  2.972795e-02
# 38  8.022454e-03
# 39  8.336686e-01
# 40  4.752397e-01
# 41  2.231969e-02
# 42  2.065300e-04
# 43  1.022721e-01
# 44  8.809528e-01
# 45  4.398541e-06
# 46  1.541289e-07
# 47  1.503279e-03
# 48  8.190212e-01
# 49  3.946622e-01
# 50  1.518190e-02
# 51  3.568426e-16
# 52  8.320353e-16
# 53  1.328597e-03
# 54  2.122381e-04
# 55  4.511848e-03
# 56  1.170364e-02
# 57  8.785522e-01
# 58  7.475689e-04
# 59  5.430692e-03
# 60  7.998087e-02
# 61  7.635854e-02
# 62  8.381844e-03
# 63  8.201117e-03
